# %%
"""
Forest Edge Image Processing - Complete Pipeline
==================================================

This script:
1. Cleans up all old backup files (*_original.png)
2. Finds ALL valid year-named images (2000, 2005, 2010, 2015, 2020 ±2 years)
3. Creates backups before cropping
4. Crops all images to keep red border, remove excess

Usage:
    python forest_edge_complete_processing.py
"""

import os
import cv2
import numpy as np
import shutil
import re

# ===== CONFIGURATION =====
FOLDER_PATH = r"G:\Hangkai\Global_Forest_edge_mapping_data\validation_samples_0p01deg_per_sample_folder\samples\output"
TARGET_YEARS = [2000, 2005, 2010, 2015, 2020]
TOLERANCE = 2
# =========================


def find_matching_image(subfolder, target_year, tolerance=2):
    """
    Find high-resolution image matching the target year within tolerance
    
    Args:
        subfolder: Path to subfolder
        target_year: Target year (e.g., 2000, 2005)
        tolerance: Year tolerance (default ±2 years)
    
    Returns:
        Path to matching PNG image or None, and the year found
    """
    year_pattern = r'(199[0-9]|20[0-1][0-9]|202[0-5])'
    
    if not os.path.exists(subfolder):
        return None, None
    
    try:
        for file in os.listdir(subfolder):
            # Skip backup files
            if file.endswith('_original.png'):
                continue
                
            if file.lower().endswith('.png'):
                match = re.search(year_pattern, file)
                if match:
                    img_year = int(match.group(1))
                    if abs(img_year - target_year) <= tolerance:
                        return os.path.join(subfolder, file), img_year
    except Exception as e:
        print(f"Warning: Error reading folder {subfolder}: {e}")
        return None, None
    
    return None, None


def crop_with_border(image_path):
    """
    Crop image keeping the red border, removing only excess outside
    Creates backup before cropping
    
    Returns:
        True if successful, False otherwise
    """
    # Create backup first
    backup_path = image_path.replace('.png', '_original.png')
    
    if os.path.exists(backup_path):
        print(f"    Warning: Backup already exists, skipping backup creation")
    else:
        shutil.copy2(image_path, backup_path)
    
    # Read image
    img = cv2.imread(image_path)
    if img is None:
        print(f"    Error: Cannot read image")
        return False
    
    original_size = f"{img.shape[1]}x{img.shape[0]}"
    
    # Convert to HSV for red detection
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    # Red color range in HSV
    lower_red1 = np.array([0, 100, 100])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])
    
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    
    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        print(f"    Warning: No red border detected (size: {original_size})")
        return False
    
    # Get bounding box of largest contour
    largest_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(largest_contour)
    
    # Keep the border, remove excess outside
    margin = 1
    x = max(0, x - margin)
    y = max(0, y - margin)
    w = min(img.shape[1] - x, w + 2 * margin)
    h = min(img.shape[0] - y, h + 2 * margin)
    
    # Crop and save
    cropped_img = img[y:y+h, x:x+w]
    cv2.imwrite(image_path, cropped_img)
    
    new_size = f"{w}x{h}"
    print(f"    Cropped: {original_size} → {new_size}")
    
    return True


def cleanup_backup_files(folder_path):
    """
    Remove all *_original.png backup files
    """
    deleted_count = 0
    
    print("=" * 80)
    print("STEP 1: CLEANING UP BACKUP FILES")
    print("=" * 80)
    print(f"Scanning folder: {folder_path}\n")
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('_original.png'):
                backup_path = os.path.join(root, file)
                print(f"Deleting: {file}")
                os.remove(backup_path)
                deleted_count += 1
    
    print(f"\n✓ Deleted {deleted_count} backup files")
    print("=" * 80)
    
    return deleted_count


def check_remaining_images(folder_path):
    """
    Check what images remain after cleanup
    """
    stats = {
        'total_samples': 0,
        'samples_with_images': 0,
        'total_images': 0,
        'images_by_year': {year: 0 for year in TARGET_YEARS}
    }
    
    print("\n" + "=" * 80)
    print("STEP 2: CHECKING REMAINING IMAGES")
    print("=" * 80)
    
    for subfolder in sorted(os.listdir(folder_path)):
        subfolder_path = os.path.join(folder_path, subfolder)
        
        if not os.path.isdir(subfolder_path):
            continue
        
        stats['total_samples'] += 1
        
        # Find valid images
        valid_images = []
        for target_year in TARGET_YEARS:
            img_path, img_year = find_matching_image(subfolder_path, target_year)
            if img_path is not None:
                valid_images.append({
                    'filename': os.path.basename(img_path),
                    'year': img_year,
                    'target_year': target_year
                })
                stats['images_by_year'][target_year] += 1
                stats['total_images'] += 1
        
        if valid_images:
            stats['samples_with_images'] += 1
    
    print(f"\nTotal samples: {stats['total_samples']}")
    print(f"Samples with images: {stats['samples_with_images']}")
    print(f"Total valid images: {stats['total_images']}")
    print(f"\nImages by target year:")
    for year in TARGET_YEARS:
        count = stats['images_by_year'][year]
        print(f"  {year}: {count} images")
    
    print("=" * 80)
    
    return stats


def crop_all_images_fresh(folder_path):
    """
    Process all valid images from scratch
    """
    stats = {
        'total_samples': 0,
        'samples_processed': 0,
        'total_images': 0,
        'successfully_cropped': 0,
        'failed': 0,
        'no_border': 0
    }
    
    print("\n" + "=" * 80)
    print("STEP 3: PROCESSING ALL IMAGES FROM SCRATCH")
    print("=" * 80)
    print(f"Target years: {TARGET_YEARS}")
    print(f"Tolerance: ±{TOLERANCE} years")
    print("=" * 80)
    print()
    
    # Process each sample folder
    for subfolder in sorted(os.listdir(folder_path)):
        subfolder_path = os.path.join(folder_path, subfolder)
        
        if not os.path.isdir(subfolder_path):
            continue
        
        stats['total_samples'] += 1
        
        # Find all valid images for this sample
        valid_images = []
        for target_year in TARGET_YEARS:
            img_path, img_year = find_matching_image(subfolder_path, target_year)
            if img_path is not None:
                valid_images.append({
                    'path': img_path,
                    'filename': os.path.basename(img_path),
                    'year': img_year,
                    'target_year': target_year
                })
        
        if valid_images:
            stats['samples_processed'] += 1
            print(f"Sample: {subfolder} ({len(valid_images)} images)")
            
            for img_info in valid_images:
                stats['total_images'] += 1
                print(f"  Processing: {img_info['filename']} (year: {img_info['year']})")
                
                success = crop_with_border(img_info['path'])
                
                if success:
                    stats['successfully_cropped'] += 1
                else:
                    stats['failed'] += 1
            
            print()  # Blank line between samples
    
    return stats


def main():
    """
    Main execution function
    """
    print("=" * 80)
    print("FOREST EDGE IMAGE PROCESSING - COMPLETE PIPELINE")
    print("=" * 80)
    print("\nThis script will:")
    print("  1. Delete all old backup files (*_original.png)")
    print("  2. Find all valid year-named images")
    print("  3. Create fresh backups")
    print("  4. Crop all images to keep red border")
    print()
    print(f"Working folder: {FOLDER_PATH}")
    print(f"Target years: {TARGET_YEARS} (±{TOLERANCE} years)")
    print("=" * 80)
    
    if not os.path.exists(FOLDER_PATH):
        print(f"\nError: Folder does not exist: {FOLDER_PATH}")
        return
    
    response = input("\nProceed? (yes/no): ").strip().lower()
    
    if response not in ['yes', 'y']:
        print("\nOperation cancelled by user.")
        return
    
    # Step 1: Cleanup
    deleted = cleanup_backup_files(FOLDER_PATH)
    
    # Step 2: Check what's left
    check_stats = check_remaining_images(FOLDER_PATH)
    
    # Step 3: Process all images
    crop_stats = crop_all_images_fresh(FOLDER_PATH)
    
    # Final summary
    print("=" * 80)
    print("COMPLETE PROCESSING SUMMARY")
    print("=" * 80)
    print(f"\nCleanup:")
    print(f"  Backup files deleted: {deleted}")
    
    print(f"\nProcessing:")
    print(f"  Total samples scanned: {crop_stats['total_samples']}")
    print(f"  Samples with images: {crop_stats['samples_processed']}")
    print(f"  Total images found: {crop_stats['total_images']}")
    print(f"  Successfully cropped: {crop_stats['successfully_cropped']}")
    print(f"  Failed to crop: {crop_stats['failed']}")
    
    if crop_stats['total_images'] > 0:
        success_rate = (crop_stats['successfully_cropped'] / crop_stats['total_images']) * 100
        print(f"\n✓ Success rate: {success_rate:.1f}%")
        print(f"  Backups saved as *_original.png")
        print(f"  All images cropped to keep red border")
    
    print("\n" + "=" * 80)
    print("PROCESSING COMPLETE!")
    print("=" * 80)


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# FOREST EDGE IMAGE PROCESSING - COMPLETE PIPELINE
# ================================================================================
#
# This script will:
#   1. Delete all old backup files (*_original.png)
#   2. Find all valid year-named images
#   3. Create fresh backups
#   4. Crop all images to keep red border
#
# Working folder: G:\Hangkai\Global_Forest_edge_mapping_data\validation_samples_0p01deg_per_sample_folder\samples\output
# Target years: [2000, 2005, 2010, 2015, 2020] (±2 years)
# ================================================================================
#
# Proceed? (yes/no): yes
# ================================================================================
# STEP 1: CLEANING UP BACKUP FILES
# ================================================================================
# Scanning folder: G:\Hangkai\Global_Forest_edge_mapping_data\validation_samples_0p01deg_per_sample_folder\samples\output
#
# Deleting: year 1999_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2019_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2021_original.png
# Deleting: year 1999_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2001_original.png
# Deleting: year 2010_original.png
# Deleting: year 2013_original.png
# Deleting: year 2021_original.png
# Deleting: year 2008_original.png
# Deleting: year 2015_original.png
# Deleting: year 2021_original.png
# Deleting: year 2008_original.png
# Deleting: year 2010_original.png
# Deleting: year 2016_original.png
# Deleting: year 2013_original.png
# Deleting: year 2018_original.png
# Deleting: year 2003_original.png
# Deleting: year 2016_original.png
# Deleting: year 2019_original.png
# Deleting: year 2007_original.png
# Deleting: year 2024_original.png
# Deleting: year 2003_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2015_original.png
# Deleting: year 2025_original.png
# Deleting: year 2006_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2017_original.png
# Deleting: year 2024_original.png
# Deleting: year 2006_original.png
# Deleting: year 2019_original.png
# Deleting: year 2002_original.png
# Deleting: year 2011_original.png
# Deleting: year 2015_original.png
# Deleting: year 2019_original.png
# Deleting: year 1999_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2009_original.png
# Deleting: year 2014_original.png
# Deleting: year 2020_original.png
# Deleting: year 2000_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2003_original.png
# Deleting: year 2005_original.png
# Deleting: year 2011_original.png
# Deleting: year 2015_original.png
# Deleting: year 2019_original.png
# Deleting: year 2003_original.png
# Deleting: year 2009_original.png
# Deleting: year 2022_original.png
# Deleting: year 2004_original.png
# Deleting: year 2013_original.png
# Deleting: year 2020_original.png
# Deleting: year 2001_original.png
# Deleting: year 2006_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2021_original.png
# Deleting: year 2010_original.png
# Deleting: year 2011_original.png
# Deleting: year 2020_original.png
# Deleting: year 2011_original.png
# Deleting: year 2015_original.png
# Deleting: year 2025_original.png
# Deleting: year 2005_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2004_original.png
# Deleting: year 2011_original.png
# Deleting: year 2014_original.png
# Deleting: year 2021_original.png
# Deleting: year 2004_original.png
# Deleting: year 2013_original.png
# Deleting: year 2020_original.png
# Deleting: year 2000_original.png
# Deleting: year 2006_original.png
# Deleting: year 2010_original.png
# Deleting: year 2016_original.png
# Deleting: year 2020_original.png
# Deleting: year 2002_original.png
# Deleting: year 2010_original.png
# Deleting: year 2018_original.png
# Deleting: year 2004_original.png
# Deleting: year 2011_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2009_original.png
# Deleting: year 2016_original.png
# Deleting: year 2021_original.png
# Deleting: year 1999_original.png
# Deleting: year 2005_original.png
# Deleting: year 2011_original.png
# Deleting: year 2014_original.png
# Deleting: year 2020_original.png
# Deleting: year 2003_original.png
# Deleting: year 2009_original.png
# Deleting: year 2014_original.png
# Deleting: year 2019_original.png
# Deleting: 2002_original.png
# Deleting: 2011_original.png
# Deleting: 2013_original.png
# Deleting: year 2017_original.png
# Deleting: year 2020_original.png
# Deleting: year 2002_original.png
# Deleting: year 2004_original.png
# Deleting: year 2009_original.png
# Deleting: year 2013_original.png
# Deleting: year 2018_original.png
# Deleting: year 2002_original.png
# Deleting: year 2004_original.png
# Deleting: year 2010_original.png
# Deleting: year 2015_original.png
# Deleting: year 2020_original.png
# Deleting: year 2009_original.png
# Deleting: year 2015_original.png
# Deleting: year 2019_original.png
# Deleting: year2003_original.png
# Deleting: year2011_original.png
# Deleting: year2015_original.png
# Deleting: year2020_original.png
# Deleting: year2005_original.png
# Deleting: year2010_original.png
# Deleting: year2015_original.png
# Deleting: year2020_original.png
# Deleting: 2002_original.png
# Deleting: 2020_original.png
# Deleting: 2006_original.png
# Deleting: 2011_original.png
# Deleting: 2015_original.png
# Deleting: 2020_original.png
# Deleting: 2016_original.png
# Deleting: 2007_original.png
# Deleting: 2012_original.png
# Deleting: 2016_original.png
# Deleting: 2020_original.png
# Deleting: 2010_original.png
# Deleting: 2015_original.png
# Deleting: 2010_original.png
# Deleting: 2021_original.png
# Deleting: 2002_original.png
# Deleting: 2014_original.png
# Deleting: 1999_original.png
# Deleting: 2005_original.png
# Deleting: 2010_original.png
# Deleting: 2015_original.png
# Deleting: 2021_original.png
# Deleting: 2005_original.png
# Deleting: 2013_original.png
# Deleting: 2021_original.png
# Deleting: 2005_original.png
# Deleting: 2011_original.png
# Deleting: 2016_original.png
# Deleting: 2019_original.png
# Deleting: 1997_original.png
# Deleting: 2005_original.png
# Deleting: 2010_original.png
# Deleting: 2015_original.png
# Deleting: 2020_original.png
# Deleting: 2005_original.png
# Deleting: 2011_original.png
# Deleting: 2015_original.png
# Deleting: 2020_original.png
# Deleting: 2020_original.png
# Deleting: 2007_original.png
# Deleting: 2011_original.png
# Deleting: 2019_original.png
# Deleting: 2011_original.png
# Deleting: 2015_original.png
# Deleting: 2020_original.png
# Deleting: 2005_original.png
# Deleting: 2010_original.png
# Deleting: 2015_original.png
# Deleting: 2020_original.png
# Deleting: 2011_original.png
# Deleting: 2021_original.png
# Deleting: 2004_original.png
# Deleting: 2020_original.png
# Deleting: 2012_original.png
# Deleting: 2003_original.png
# Deleting: 2013_original.png
# Deleting: 2016_original.png
# Deleting: 2002_original.png
# Deleting: 2007_original.png
# Deleting: 2016_original.png
# Deleting: 2020_original.png
# Deleting: 2004_original.png
# Deleting: 2010_original.png
# Deleting: 2016_original.png
# Deleting: 2019_original.png
#
# ✓ Deleted 209 backup files
# ================================================================================
#
# ================================================================================
# STEP 2: CHECKING REMAINING IMAGES
# ================================================================================
#
# Total samples: 100
# Samples with images: 100
# Total valid images: 346
#
# Images by target year:
#   2000: 26 images
#   2005: 63 images
#   2010: 82 images
#   2015: 86 images
#   2020: 89 images
# ================================================================================
#
# ================================================================================
# STEP 3: PROCESSING ALL IMAGES FROM SCRATCH
# ================================================================================
# Target years: [2000, 2005, 2010, 2015, 2020]
# Tolerance: ±2 years
# ================================================================================
#
# Sample: sample_00106 (5 images)
#   Processing: year 1999.png (year: 1999)
#     Cropped: 772x890 → 772x890
#   Processing: year 2005.png (year: 2005)
#     Cropped: 770x889 → 770x889
#   Processing: year 2010.png (year: 2010)
#     Cropped: 771x890 → 771x890
#   Processing: year 2015.png (year: 2015)
#     Cropped: 770x890 → 770x890
#   Processing: year 2019.png (year: 2019)
#     Cropped: 787x916 → 771x890
#
# Sample: sample_00113 (3 images)
#   Processing: year 2005.png (year: 2005)
#     Cropped: 595x865 → 595x865
#   Processing: year 2010.png (year: 2010)
#     Cropped: 766x1113 → 766x1113
#   Processing: year 2021.png (year: 2021)
#     Cropped: 673x977 → 673x977
#
# Sample: sample_00114 (5 images)
#   Processing: year 1999.png (year: 1999)
#     Cropped: 700x810 → 700x810
#   Processing: year 2005.png (year: 2005)
#     Cropped: 776x898 → 776x898
#   Processing: year 2010.png (year: 2010)
#     Cropped: 775x897 → 775x897
#   Processing: year 2015.png (year: 2015)
#     Cropped: 776x898 → 776x898
#   Processing: year 2020.png (year: 2020)
#     Cropped: 797x921 → 776x898
#
# Sample: sample_00120 (4 images)
#   Processing: year 2001.png (year: 2001)
#     Cropped: 779x1001 → 779x1001
#   Processing: year 2010.png (year: 2010)
#     Cropped: 779x1001 → 779x1001
#   Processing: year 2013.png (year: 2013)
#     Cropped: 787x1016 → 779x1001
#   Processing: year 2021.png (year: 2021)
#     Cropped: 780x1001 → 780x1001
#
# Sample: sample_00121 (3 images)
#   Processing: year 2008.png (year: 2008)
#     Cropped: 586x1140 → 586x1140
#   Processing: year 2015.png (year: 2015)
#     Cropped: 577x1132 → 577x1132
#   Processing: year 2021.png (year: 2021)
#     Cropped: 594x1148 → 576x1132
#
# Sample: sample_00123 (2 images)
#   Processing: year 2008.png (year: 2008)
#     Cropped: 458x1009 → 458x1009
#   Processing: year 2016.png (year: 2016)
#     Cropped: 454x1000 → 454x1000
#
# Sample: sample_00124 (2 images)
#   Processing: year 2013.png (year: 2013)
#     Cropped: 854x862 → 854x862
#   Processing: year 2018.png (year: 2018)
#     Cropped: 854x862 → 854x862
#
# Sample: sample_00168 (3 images)
#   Processing: 2012.PNG (year: 2012)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 425x764 → 425x764
#   Processing: 2014.PNG (year: 2014)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 425x764 → 425x764
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 425x764 → 425x764
#
# Sample: sample_00169 (1 images)
#   Processing: 2012.PNG (year: 2012)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 914x948 → 914x948
#
# Sample: sample_00170 (3 images)
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 921x919 → 921x919
#   Processing: 2013.PNG (year: 2013)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 920x919 → 920x919
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 921x919 → 921x919
#
# Sample: sample_00172 (4 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 919x932 → 919x932
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 919x932 → 919x932
#   Processing: 2017.PNG (year: 2017)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 919x932 → 919x932
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 919x932 → 919x932
#
# Sample: sample_00174 (4 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 848x1018 → 848x1018
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 847x1018 → 847x1018
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 848x1018 → 848x1018
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 847x1018 → 847x1018
#
# Sample: sample_00177 (3 images)
#   Processing: 2012.PNG (year: 2012)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 837x859 → 837x859
#   Processing: 2013.PNG (year: 2013)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 837x859 → 837x859
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 837x859 → 837x859
#
# Sample: sample_00182 (3 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 837x859 → 837x859
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 907x916 → 907x916
#   Processing: 2018.PNG (year: 2018)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 906x915 → 906x915
#
# Sample: sample_00188 (4 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 822x1004 → 822x1004
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 821x992 → 821x992
#   Processing: 2014.PNG (year: 2014)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 821x992 → 821x992
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 821x992 → 821x992
#
# Sample: sample_00203 (5 images)
#   Processing: 1998.PNG (year: 1998)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 742x1042 → 742x1042
#   Processing: 2003.PNG (year: 2003)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 743x1044 → 743x1044
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 742x1042 → 742x1042
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 743x1044 → 743x1044
#   Processing: 2018.PNG (year: 2018)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 743x1043 → 743x1043
#
# Sample: sample_00228 (2 images)
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 462x912 → 462x912
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 462x912 → 462x912
#
# Sample: sample_00232 (5 images)
#   Processing: 2000.PNG (year: 2000)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 623x755 → 623x755
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 624x755 → 624x755
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 623x755 → 623x755
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 624x755 → 624x755
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 623x755 → 623x755
#
# Sample: sample_00302 (5 images)
#   Processing: 2001.PNG (year: 2001)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1006x1020 → 1006x1020
#   Processing: 2007.PNG (year: 2007)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1006x1020 → 1006x1020
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1006x1020 → 1006x1020
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1006x1020 → 1006x1020
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1007x1020 → 1007x1020
#
# Sample: sample_00424 (3 images)
#   Processing: 2004.PNG (year: 2004)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 552x928 → 552x928
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 552x928 → 552x928
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 552x928 → 552x928
#
# Sample: sample_00467 (3 images)
#   Processing: 2008.PNG (year: 2008)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1023x1022 → 1023x1022
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1023x1022 → 1023x1022
#   Processing: 2021.PNG (year: 2021)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1028x1025 → 1028x1025
#
# Sample: sample_00476 (2 images)
#   Processing: 2003.PNG (year: 2003)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 636x1017 → 636x1017
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 636x1017 → 636x1017
#
# Sample: sample_00502 (3 images)
#   Processing: year 2003.png (year: 2003)
#     Cropped: 374x665 → 374x665
#   Processing: year 2016.png (year: 2016)
#     Cropped: 374x664 → 374x664
#   Processing: year 2019.png (year: 2019)
#     Cropped: 449x702 → 374x665
#
# Sample: sample_00507 (1 images)
#   Processing: year 2007.png (year: 2007)
#     Cropped: 783x838 → 783x838
#
# Sample: sample_00508 (4 images)
#   Processing: year 2003.png (year: 2003)
#     Cropped: 673x876 → 673x876
#   Processing: year 2010.png (year: 2010)
#     Cropped: 673x876 → 673x876
#   Processing: year 2015.png (year: 2015)
#     Cropped: 673x876 → 673x876
#   Processing: year 2020.png (year: 2020)
#     Cropped: 736x915 → 672x876
#
# Sample: sample_00538 (1 images)
#   Processing: year 2015.png (year: 2015)
#     Cropped: 366x836 → 366x836
#
# Sample: sample_00539 (4 images)
#   Processing: year 2006.png (year: 2006)
#     Cropped: 562x591 → 562x591
#   Processing: year 2010.png (year: 2010)
#     Cropped: 562x591 → 562x591
#   Processing: year 2015.png (year: 2015)
#     Cropped: 563x592 → 563x592
#   Processing: year 2020.png (year: 2020)
#     Cropped: 619x640 → 562x597
#
# Sample: sample_00540 (1 images)
#   Processing: year 2017.png (year: 2017)
#     Cropped: 541x969 → 541x969
#
# Sample: sample_00541 (2 images)
#   Processing: year 2006.png (year: 2006)
#     Cropped: 375x676 → 375x676
#   Processing: year 2019.png (year: 2019)
#     Cropped: 375x676 → 375x676
#
# Sample: sample_00542 (4 images)
#   Processing: year 2002.png (year: 2002)
#     Cropped: 419x731 → 419x731
#   Processing: year 2011.png (year: 2011)
#     Cropped: 418x731 → 418x731
#   Processing: year 2015.png (year: 2015)
#     Cropped: 418x730 → 418x730
#   Processing: year 2019.png (year: 2019)
#     Cropped: 514x778 → 419x731
#
# Sample: sample_00545 (5 images)
#   Processing: year 1999.png (year: 1999)
#     Cropped: 923x1071 → 923x1071
#   Processing: year 2005.png (year: 2005)
#     Cropped: 923x1071 → 923x1071
#   Processing: year 2010.png (year: 2010)
#     Cropped: 923x1070 → 923x1070
#   Processing: year 2015.png (year: 2015)
#     Cropped: 923x1070 → 923x1070
#   Processing: year 2020.png (year: 2020)
#     Cropped: 977x1116 → 923x1070
#
# Sample: sample_00546 (3 images)
#   Processing: year 2009.png (year: 2009)
#     Cropped: 704x1003 → 704x1003
#   Processing: year 2014.png (year: 2014)
#     Cropped: 704x1003 → 704x1003
#   Processing: year 2020.png (year: 2020)
#     Cropped: 704x1005 → 704x1005
#
# Sample: sample_00551 (4 images)
#   Processing: year 2000.png (year: 2000)
#     Cropped: 602x602 → 602x602
#   Processing: year 2010.png (year: 2010)
#     Cropped: 610x605 → 610x605
#   Processing: year 2015.png (year: 2015)
#     Cropped: 635x632 → 635x632
#   Processing: year 2020.png (year: 2020)
#     Cropped: 626x624 → 602x602
#
# Sample: sample_00552 (4 images)
#   Processing: year 2003.png (year: 2003)
#     Cropped: 663x827 → 663x827
#   Processing: year 2011.png (year: 2011)
#     Cropped: 663x827 → 663x827
#   Processing: year 2015.png (year: 2015)
#     Cropped: 663x827 → 663x827
#   Processing: year 2019.png (year: 2019)
#     Cropped: 689x846 → 663x827
#
# Sample: sample_00553 (3 images)
#   Processing: year 2003.png (year: 2003)
#     Cropped: 554x970 → 554x970
#   Processing: year 2009.png (year: 2009)
#     Cropped: 554x970 → 554x970
#   Processing: year 2022.png (year: 2022)
#     Cropped: 554x970 → 554x970
#
# Sample: sample_00592 (3 images)
#   Processing: year 2004.png (year: 2004)
#     Cropped: 816x880 → 816x880
#   Processing: year 2013.png (year: 2013)
#     Cropped: 816x880 → 816x880
#   Processing: year 2020.png (year: 2020)
#     Cropped: 817x880 → 817x880
#
# Sample: sample_00598 (5 images)
#   Processing: year 2001.png (year: 2001)
#     Cropped: 716x880 → 716x880
#   Processing: year 2006.png (year: 2006)
#     Cropped: 717x880 → 717x880
#   Processing: year 2010.png (year: 2010)
#     Cropped: 716x880 → 716x880
#   Processing: year 2015.png (year: 2015)
#     Cropped: 716x880 → 716x880
#   Processing: year 2021.png (year: 2021)
#     Cropped: 777x927 → 716x880
#
# Sample: sample_00600 (2 images)
#   Processing: year 2010.png (year: 2010)
#     Cropped: 471x806 → 471x806
#   Processing: year 2020.png (year: 2020)
#     Cropped: 470x806 → 470x806
#
# Sample: sample_00601 (2 images)
#   Processing: year 2011.png (year: 2011)
#     Cropped: 544x899 → 544x899
#   Processing: year 2015.png (year: 2015)
#     Cropped: 544x898 → 544x898
#
# Sample: sample_00605 (4 images)
#   Processing: year 2005.png (year: 2005)
#     Cropped: 714x831 → 714x831
#   Processing: year 2010.png (year: 2010)
#     Cropped: 714x831 → 714x831
#   Processing: year 2015.png (year: 2015)
#     Cropped: 714x831 → 714x831
#   Processing: year 2020.png (year: 2020)
#     Cropped: 736x848 → 714x831
#
# Sample: sample_00607 (4 images)
#   Processing: year 2004.png (year: 2004)
#     Cropped: 837x972 → 837x972
#   Processing: year 2011.png (year: 2011)
#     Cropped: 837x972 → 837x972
#   Processing: year 2014.png (year: 2014)
#     Cropped: 856x989 → 837x972
#   Processing: year 2021.png (year: 2021)
#     Cropped: 889x1032 → 889x1032
#
# Sample: sample_00608 (3 images)
#   Processing: year 2004.png (year: 2004)
#     Cropped: 917x961 → 917x961
#   Processing: year 2013.png (year: 2013)
#     Cropped: 917x961 → 917x961
#   Processing: year 2020.png (year: 2020)
#     Cropped: 918x961 → 918x961
#
# Sample: sample_00610 (5 images)
#   Processing: year 2000.png (year: 2000)
#     Cropped: 835x1004 → 835x1004
#   Processing: year 2006.png (year: 2006)
#     Cropped: 835x1004 → 835x1004
#   Processing: year 2010.png (year: 2010)
#     Cropped: 835x1004 → 835x1004
#   Processing: year 2016.png (year: 2016)
#     Cropped: 835x1004 → 835x1004
#   Processing: year 2020.png (year: 2020)
#     Cropped: 855x1034 → 835x1004
#
# Sample: sample_00615 (3 images)
#   Processing: year 2002.png (year: 2002)
#     Cropped: 693x704 → 693x704
#   Processing: year 2010.png (year: 2010)
#     Cropped: 695x707 → 695x707
#   Processing: year 2018.png (year: 2018)
#     Cropped: 694x704 → 694x704
#
# Sample: sample_00616 (4 images)
#   Processing: year 2004.png (year: 2004)
#     Cropped: 790x827 → 790x827
#   Processing: year 2011.png (year: 2011)
#     Cropped: 789x827 → 789x827
#   Processing: year 2015.png (year: 2015)
#     Cropped: 790x827 → 790x827
#   Processing: year 2020.png (year: 2020)
#     Cropped: 863x882 → 807x842
#
# Sample: sample_00679 (3 images)
#   Processing: year 2009.png (year: 2009)
#     Cropped: 744x746 → 744x746
#   Processing: year 2016.png (year: 2016)
#     Cropped: 744x746 → 744x746
#   Processing: year 2021.png (year: 2021)
#     Cropped: 754x763 → 746x746
#
# Sample: sample_00680 (5 images)
#   Processing: year 1999.png (year: 1999)
#     Cropped: 673x792 → 673x792
#   Processing: year 2005.png (year: 2005)
#     Cropped: 673x792 → 673x792
#   Processing: year 2011.png (year: 2011)
#     Cropped: 673x794 → 673x794
#   Processing: year 2014.png (year: 2014)
#     Cropped: 680x806 → 673x792
#   Processing: year 2020.png (year: 2020)
#     Cropped: 673x792 → 673x792
#
# Sample: sample_00689 (4 images)
#   Processing: year 2003.png (year: 2003)
#     Cropped: 478x814 → 478x814
#   Processing: year 2009.png (year: 2009)
#     Cropped: 478x814 → 478x814
#   Processing: year 2014.png (year: 2014)
#     Cropped: 478x814 → 478x814
#   Processing: year 2019.png (year: 2019)
#     Cropped: 478x814 → 478x814
#
# Sample: sample_00691 (4 images)
#   Processing: 2002.png (year: 2002)
#     Cropped: 861x860 → 861x860
#   Processing: 2011.png (year: 2011)
#     Cropped: 861x860 → 861x860
#   Processing: 2013.png (year: 2013)
#     Cropped: 873x877 → 861x860
#   Processing: year 2020.png (year: 2020)
#     Cropped: 868x875 → 861x860
#
# Sample: sample_00695 (5 images)
#   Processing: year 2002.png (year: 2002)
#     Cropped: 752x780 → 752x780
#   Processing: year 2004.png (year: 2004)
#     Cropped: 754x788 → 735x771
#   Processing: year 2009.png (year: 2009)
#     Cropped: 735x771 → 735x771
#   Processing: year 2013.png (year: 2013)
#     Cropped: 736x785 → 736x785
#   Processing: year 2018.png (year: 2018)
#     Cropped: 735x771 → 735x771
#
# Sample: sample_00701 (5 images)
#   Processing: year 2002.png (year: 2002)
#     Cropped: 706x762 → 706x762
#   Processing: year 2004.png (year: 2004)
#     Cropped: 717x782 → 706x761
#   Processing: year 2010.png (year: 2010)
#     Cropped: 706x762 → 706x762
#   Processing: year 2015.png (year: 2015)
#     Cropped: 706x762 → 706x762
#   Processing: year 2020.png (year: 2020)
#     Cropped: 734x788 → 706x762
#
# Sample: sample_00706 (3 images)
#   Processing: year 2009.png (year: 2009)
#     Cropped: 671x1067 → 671x1067
#   Processing: year 2015.png (year: 2015)
#     Cropped: 671x1067 → 671x1067
#   Processing: year 2019.png (year: 2019)
#     Cropped: 693x1110 → 671x1067
#
# Sample: sample_01010_A (4 images)
#   Processing: year2003.png (year: 2003)
#     Cropped: 982x1098 → 982x1098
#   Processing: year2011.png (year: 2011)
#     Cropped: 981x1090 → 981x1090
#   Processing: year2015.png (year: 2015)
#     Cropped: 980x1089 → 980x1089
#   Processing: year2020.png (year: 2020)
#     Cropped: 1004x1107 → 981x1089
#
# Sample: sample_01019_A (5 images)
#   Processing: year 2002.PNG (year: 2002)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 823x947 → 823x947
#   Processing: year2005.png (year: 2005)
#     Cropped: 822x947 → 822x947
#   Processing: year2010.png (year: 2010)
#     Cropped: 822x946 → 822x946
#   Processing: year2015.png (year: 2015)
#     Cropped: 823x946 → 823x946
#   Processing: year2020.png (year: 2020)
#     Cropped: 876x1005 → 841x970
#
# Sample: sample_01026_B (3 images)
#   Processing: 2002.png (year: 2002)
#     Cropped: 898x898 → 898x898
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 899x898 → 899x898
#   Processing: 2020.png (year: 2020)
#     Cropped: 899x898 → 899x898
#
# Sample: sample_01029_A (4 images)
#   Processing: 2006.png (year: 2006)
#     Cropped: 521x948 → 521x948
#   Processing: 2011.png (year: 2011)
#     Cropped: 529x957 → 529x957
#   Processing: 2015.png (year: 2015)
#     Cropped: 529x957 → 529x957
#   Processing: 2020.png (year: 2020)
#     Cropped: 586x1001 → 530x957
#
# Sample: sample_01030_B (1 images)
#   Processing: 2016.png (year: 2016)
#     Cropped: 968x975 → 968x975
#
# Sample: sample_01038_B (4 images)
#   Processing: 2007.png (year: 2007)
#     Cropped: 964x1068 → 964x1068
#   Processing: 2012.png (year: 2012)
#     Cropped: 964x1068 → 964x1068
#   Processing: 2016.png (year: 2016)
#     Cropped: 964x1067 → 964x1067
#   Processing: 2020.png (year: 2020)
#     Cropped: 1018x1105 → 964x1067
#
# Sample: sample_01040_A (3 images)
#   Processing: 2010.png (year: 2010)
#     Cropped: 749x840 → 749x840
#   Processing: 2015.png (year: 2015)
#     Cropped: 749x840 → 749x840
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 749x840 → 749x840
#
# Sample: sample_01044_C (2 images)
#   Processing: 2010.png (year: 2010)
#     Cropped: 604x622 → 604x622
#   Processing: 2021.png (year: 2021)
#     Cropped: 640x660 → 640x660
#
# Sample: sample_01050_B (4 images)
#   Processing: 2002.png (year: 2002)
#     Cropped: 839x848 → 839x848
#   Processing: 2004.PNG (year: 2004)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 838x848 → 838x848
#   Processing: 2008.PNG (year: 2008)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 838x848 → 838x848
#   Processing: 2014.png (year: 2014)
#     Cropped: 839x848 → 839x848
#
# Sample: sample_01094_A (5 images)
#   Processing: 1999.png (year: 1999)
#     Cropped: 985x1125 → 985x1125
#   Processing: 2005.png (year: 2005)
#     Cropped: 985x1125 → 985x1125
#   Processing: 2010.png (year: 2010)
#     Cropped: 985x1125 → 985x1125
#   Processing: 2015.png (year: 2015)
#     Cropped: 985x1125 → 985x1125
#   Processing: 2021.png (year: 2021)
#     Cropped: 1012x1145 → 985x1125
#
# Sample: sample_01095_A (5 images)
#   Processing: year 2001.PNG (year: 2001)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 955x1002 → 955x1002
#   Processing: year 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 955x1002 → 955x1002
#   Processing: year 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 954x1001 → 954x1001
#   Processing: year 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 974x1002 → 974x1002
#   Processing: year 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 967x1002 → 967x1002
#
# Sample: sample_01112_A (4 images)
#   Processing: 2005.png (year: 2005)
#     Cropped: 878x892 → 878x892
#   Processing: 2008.PNG (year: 2008)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 878x892 → 878x892
#   Processing: 2013.png (year: 2013)
#     Cropped: 878x892 → 878x892
#   Processing: 2021.png (year: 2021)
#     Cropped: 878x892 → 878x892
#
# Sample: sample_01115_A (4 images)
#   Processing: 2005.png (year: 2005)
#     Cropped: 989x1004 → 989x1004
#   Processing: 2011.png (year: 2011)
#     Cropped: 989x1004 → 989x1004
#   Processing: 2016.png (year: 2016)
#     Cropped: 989x1004 → 989x1004
#   Processing: 2019.png (year: 2019)
#     Cropped: 1020x1040 → 997x1015
#
# Sample: sample_01117_S (4 images)
#   Processing: 2005.png (year: 2005)
#     Cropped: 880x1057 → 880x1057
#   Processing: 2010.png (year: 2010)
#     Cropped: 880x1057 → 880x1057
#   Processing: 2015.png (year: 2015)
#     Cropped: 880x1057 → 880x1057
#   Processing: 2020.png (year: 2020)
#     Cropped: 927x1103 → 880x1057
#
# Sample: sample_01132_A (4 images)
#   Processing: 2005.png (year: 2005)
#     Cropped: 858x973 → 858x973
#   Processing: 2011.png (year: 2011)
#     Cropped: 858x973 → 858x973
#   Processing: 2015.png (year: 2015)
#     Cropped: 857x973 → 857x973
#   Processing: 2020.png (year: 2020)
#     Cropped: 883x997 → 858x973
#
# Sample: sample_01140_B (2 images)
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 512x1168 → 512x1168
#   Processing: 2020.png (year: 2020)
#     Cropped: 529x1192 → 512x1168
#
# Sample: sample_01181_B (4 images)
#   Processing: 2007.png (year: 2007)
#     Cropped: 642x915 → 642x915
#   Processing: 2011.png (year: 2011)
#     Cropped: 642x915 → 642x915
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 643x916 → 643x916
#   Processing: 2019.png (year: 2019)
#     Cropped: 731x990 → 642x915
#
# Sample: sample_01182_C (3 images)
#   Processing: 2011.png (year: 2011)
#     Cropped: 776x812 → 776x812
#   Processing: 2015.png (year: 2015)
#     Cropped: 776x811 → 776x811
#   Processing: 2020.png (year: 2020)
#     Cropped: 797x844 → 775x811
#
# Sample: sample_01183_B (5 images)
#   Processing: 1998.PNG (year: 1998)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 853x1010 → 853x1010
#   Processing: 2005.png (year: 2005)
#     Cropped: 853x1010 → 853x1010
#   Processing: 2010.png (year: 2010)
#     Cropped: 856x1014 → 856x1014
#   Processing: 2015.png (year: 2015)
#     Cropped: 853x1010 → 853x1010
#   Processing: 2020.png (year: 2020)
#     Cropped: 897x1057 → 854x1012
#
# Sample: sample_01188_B (3 images)
#   Processing: 2011.png (year: 2011)
#     Cropped: 689x980 → 689x980
#   Processing: 2017.PNG (year: 2017)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 689x980 → 689x980
#   Processing: 2021.png (year: 2021)
#     Cropped: 734x1032 → 690x980
#
# Sample: sample_01206_B (3 images)
#   Processing: 2004.png (year: 2004)
#     Cropped: 1077x1099 → 1077x1099
#   Processing: 2008.PNG (year: 2008)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1091x1111 → 1091x1111
#   Processing: 2020.png (year: 2020)
#     Cropped: 1101x1111 → 1101x1111
#
# Sample: sample_01242_C (1 images)
#   Processing: 2012.png (year: 2012)
#     Cropped: 1105x1107 → 1105x1107
#
# Sample: sample_01303_A (3 images)
#   Processing: 2003.png (year: 2003)
#     Cropped: 909x971 → 909x971
#   Processing: 2013.png (year: 2013)
#     Cropped: 909x971 → 909x971
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 909x971 → 909x971
#
# Sample: sample_01313_A (5 images)
#   Processing: 2002.png (year: 2002)
#     Cropped: 1070x1074 → 1070x1074
#   Processing: 2007.png (year: 2007)
#     Cropped: 1070x1074 → 1070x1074
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1070x1074 → 1070x1074
#   Processing: 2016.png (year: 2016)
#     Cropped: 1070x1074 → 1070x1074
#   Processing: 2020.png (year: 2020)
#     Cropped: 1104x1104 → 1071x1074
#
# Sample: sample_01489_A (4 images)
#   Processing: 2004.png (year: 2004)
#     Cropped: 1040x1114 → 1040x1114
#   Processing: 2010.png (year: 2010)
#     Cropped: 1040x1114 → 1040x1114
#   Processing: 2016.png (year: 2016)
#     Cropped: 1041x1117 → 1041x1117
#   Processing: 2019.png (year: 2019)
#     Cropped: 1067x1138 → 1040x1115
#
# Sample: sample_01502 (3 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 408x867 → 408x867
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 408x867 → 408x867
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 408x867 → 408x867
#
# Sample: sample_01505 (3 images)
#   Processing: 2012.PNG (year: 2012)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 810x899 → 810x899
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 811x899 → 811x899
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 811x899 → 811x899
#
# Sample: sample_01506 (4 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 420x796 → 420x796
#   Processing: 2009.PNG (year: 2009)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 418x784 → 418x784
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 419x784 → 419x784
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 418x784 → 418x784
#
# Sample: sample_01507 (4 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 689x857 → 689x857
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 690x857 → 690x857
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 690x857 → 690x857
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 689x857 → 689x857
#
# Sample: sample_01531 (5 images)
#   Processing: 1999.PNG (year: 1999)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 606x694 → 606x694
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 606x694 → 606x694
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 606x694 → 606x694
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 605x694 → 605x694
#   Processing: 2021.PNG (year: 2021)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 606x694 → 606x694
#
# Sample: sample_01541 (3 images)
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 576x1095 → 576x1095
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 576x1095 → 576x1095
#   Processing: 2022.PNG (year: 2022)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 576x1094 → 576x1094
#
# Sample: sample_01547 (4 images)
#   Processing: 2004.PNG (year: 2004)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 845x1057 → 845x1057
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 845x1057 → 845x1057
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 845x1057 → 845x1057
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 845x1057 → 845x1057
#
# Sample: sample_01548 (5 images)
#   Processing: 1999.PNG (year: 1999)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 902x1031 → 902x1031
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 902x1031 → 902x1031
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 903x1032 → 903x1032
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 839x961 → 839x961
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 839x961 → 839x961
#
# Sample: sample_01549 (3 images)
#   Processing: 2009.PNG (year: 2009)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 638x1014 → 638x1014
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 638x1017 → 638x1017
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 639x1020 → 639x1020
#
# Sample: sample_01561 (4 images)
#   Processing: 2002.PNG (year: 2002)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 933x945 → 933x945
#   Processing: 2009.PNG (year: 2009)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 933x945 → 933x945
#   Processing: 2013.PNG (year: 2013)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 933x945 → 933x945
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 933x945 → 933x945
#
# Sample: sample_01571 (2 images)
#   Processing: 2014.PNG (year: 2014)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 763x964 → 763x964
#   Processing: 2022.PNG (year: 2022)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 763x964 → 763x964
#
# Sample: sample_01581 (2 images)
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 721x772 → 721x772
#   Processing: 2018.PNG (year: 2018)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 720x772 → 720x772
#
# Sample: sample_01596 (2 images)
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 474x932 → 474x932
#   Processing: 2014.PNG (year: 2014)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 474x932 → 474x932
#
# Sample: sample_01601 (3 images)
#   Processing: 2005.PNG (year: 2005)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 771x922 → 771x922
#   Processing: 2008.PNG (year: 2008)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 771x922 → 771x922
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 788x937 → 788x937
#
# Sample: sample_01603 (4 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 878x986 → 878x986
#   Processing: 2009.PNG (year: 2009)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 878x986 → 878x986
#   Processing: 2014.PNG (year: 2014)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 878x986 → 878x986
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 878x986 → 878x986
#
# Sample: sample_01605 (4 images)
#   Processing: 2007.PNG (year: 2007)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 805x1108 → 805x1108
#   Processing: 2009.PNG (year: 2009)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 802x1108 → 802x1108
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 802x1108 → 802x1108
#   Processing: 2019.PNG (year: 2019)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 802x1108 → 802x1108
#
# Sample: sample_01607 (3 images)
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 681x732 → 681x732
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 681x732 → 681x732
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 681x732 → 681x732
#
# Sample: sample_01608 (4 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 808x938 → 808x938
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 808x938 → 808x938
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 808x939 → 808x939
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 808x939 → 808x939
#
# Sample: sample_01615 (3 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 911x914 → 911x914
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 911x914 → 911x914
#   Processing: 2021.PNG (year: 2021)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 910x913 → 910x913
#
# Sample: sample_01620 (3 images)
#   Processing: 2003.PNG (year: 2003)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1032x1051 → 1032x1051
#   Processing: 2013.PNG (year: 2013)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1032x1051 → 1032x1051
#   Processing: 2022.PNG (year: 2022)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 1032x1051 → 1032x1051
#
# Sample: sample_01657 (4 images)
#   Processing: 2003.PNG (year: 2003)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 728x918 → 728x918
#   Processing: 2011.PNG (year: 2011)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 728x918 → 728x918
#   Processing: 2016.PNG (year: 2016)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 729x926 → 729x926
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 728x919 → 728x919
#
# Sample: sample_01681 (4 images)
#   Processing: 2003.PNG (year: 2003)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 799x971 → 799x971
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 801x971 → 801x971
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 800x971 → 800x971
#   Processing: 2021.PNG (year: 2021)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 800x971 → 800x971
#
# Sample: sample_01796 (4 images)
#   Processing: 2006.PNG (year: 2006)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 749x989 → 749x989
#   Processing: 2010.PNG (year: 2010)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 748x987 → 748x987
#   Processing: 2015.PNG (year: 2015)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 749x989 → 749x989
#   Processing: 2020.PNG (year: 2020)
#     Warning: Backup already exists, skipping backup creation
#     Cropped: 748x989 → 748x989
#
# ================================================================================
# COMPLETE PROCESSING SUMMARY
# ================================================================================
#
# Cleanup:
#   Backup files deleted: 209
#
# Processing:
#   Total samples scanned: 100
#   Samples with images: 100
#   Total images found: 346
#   Successfully cropped: 346
#   Failed to crop: 0
#
# ✓ Success rate: 100.0%
#   Backups saved as *_original.png
#   All images cropped to keep red border
#
# ================================================================================
# PROCESSING COMPLETE!
# ================================================================================
